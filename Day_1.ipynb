# %%
import numpy as np

# %%
### Import the IDs list
ID_list_txt = open('ID_list.txt','r')
ID_list = ID_list_txt.read().splitlines()
for i, IDs in enumerate(ID_list) :
    ID_list[i] = IDs.split("   ")
ID_list = np.array(ID_list, dtype=int)
print(ID_list)
# Out:
# [[77442 88154]
#  [71181 76363]
#  [49755 69158]
#  ...
#  [69182 95805]
#  [59092 67571]
#  [29363 98020]]

# %%
### Separate and sort each lists
ID_list_1 = ID_list[:,0]
ID_list_2 = ID_list[:,1]
ID_list_1_sorted = np.sort(ID_list_1)
ID_list_2_sorted = np.sort(ID_list_2)

print(ID_list_1[:10], ID_list_1_sorted[:10])
# Out:
# [77442 71181 49755 38798 89857 96168 68503 52053 27070 78107] [10066 10149 10186 10193 10468 10479 10730 10741 10780 10872]

# %%
### Compute distance between lists
ID_difference_list = abs(ID_list_1_sorted - ID_list_2_sorted)
ID_distance = np.sum(ID_difference_list)
print(ID_distance)
# Out:
# 2176849
